# %% [markdown]
# <a href="https://colab.research.google.com/github/naylaizismendes/KitchenSink/blob/main/Untitled16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
secret_number = 777

print(
"""
+===================================+
| Bem vindo ao meu jogo, trouxa!    |
| Insira um número inteiro          |
| e adivinhar o número que tenho    |
| escolhidos para você.             |
| Então, qual é o número secreto?   |
+===================================+
""")
while True:
  secret_number=int(input("insira um numero,trouxa: "))
  if secret_number== 777:
    print("Muito bem, trouxa! Você está livre!")
    break
  print("Ha ha! Você está preso no meu loop!")
# Out:
# +===================================+
# | Bem vindo ao meu jogo, trouxa!    |
# | Insira um número inteiro          |
# | e adivinhar o número que tenho    |
# | escolhidos para você.             |
# | Então, qual é o número secreto?   |
# +===================================+
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-ab50f796644a> in <cell line: 13>()
#      12 """)
#      13 while True:
# ---> 14   secret_number=int(input("insira um numero,trouxa: "))
#      15   if secret_number== 777:
#      16     print("Muito bem, trouxa! Você está livre!")
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
# ...

# %%
for i in range(2,8,3):
  print("O valor de i e atualmente")
# Out:
# O valor de i e atualmente
# O valor de i e atualmente

# %%
for i in range(2, 8):
    print("O valor de i é atualmente", i)
# Out:
# O valor de i é atualmente 2
# O valor de i é atualmente 3
# O valor de i é atualmente 4
# O valor de i é atualmente 5
# O valor de i é atualmente 6
# O valor de i é atualmente 7

# %%
for i in range(2, 8, 3):
  print("O valor de i é atualmente", i)
# Out:
# O valor de i é atualmente 2
# O valor de i é atualmente 5

# %%
import time
for i in range (0,5):
  print(i,"Missipi")
  time.sleep(1)
  print("Pronto ou não, aqui vou eu!")
# Out:
# 0 Missipi
# Pronto ou não, aqui vou eu!
# 1 Missipi
# Pronto ou não, aqui vou eu!
# 2 Missipi
# Pronto ou não, aqui vou eu!
# 3 Missipi
# Pronto ou não, aqui vou eu!
# 4 Missipi
# Pronto ou não, aqui vou eu!

# %%
for i in range(0,3):
  print('oi')
# Out:
# oi
# oi
# oi

# %%
x=0
for i in range(0, 1001):
  x= x+i
  print(x)
# Out:
# 0
# 1
# 3
# 6
# 10
# 15
# 21
# 28
# 36
# 45
# 55
# 66
# 78
# 91
# 105
# 120
# 136
# 153
# 171
# 190
# 210
# 231
# 253
# 276
# 300
# 325
# 351
# 378
# 406
# 435
# 465
# 496
# 528
# 561
# 595
# 630
# 666
# 703
# 741
# 780
# 820
# 861
# 903
# 946
# 990
# 1035
# 1081
# 1128
# 1176
# 1225
# 1275
# 1326
# 1378
# 1431
# 1485
# 1540
# 1596
# 1653
# 1711
# 1770
# 1830
# 1891
# 1953
# 2016
# 2080
# 2145
# 2211
# 2278
# 2346
# 2415
# 2485
# 2556
# 2628
# 2701
# 2775
# 2850
# 2926
# 3003
# 3081
# 3160
# 3240
# 3321
# 3403
# 3486
# 3570
# 3655
# 3741
# 3828
# 3916
# 4005
# 4095
# 4186
# 4278
# 4371
# 4465
# 4560
# 4656
# 4753
# 4851
# 4950
# 5050
# 5151
# 5253
# 5356
# 5460
# 5565
# 5671
# 5778
# 5886
# 5995
# 6105
# 6216
# 6328
# 6441
# 6555
# 6670
# 6786
# 6903
# 7021
# 7140
# 7260
# 7381
# 7503
# 7626
# 7750
# 7875
# 8001
# 8128
# 8256
# 8385
# 8515
# 8646
# 8778
# 8911
# 9045
# 9180
# 9316
# 9453
# 9591
# 9730
# 9870
# 10011
# 10153
# 10296
# 10440
# 10585
# 10731
# 10878
# 11026
# 11175
# ...
